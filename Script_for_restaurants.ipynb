# %%
from requests_html import HTMLSession
import re
import random

# %%
def restaurant_roulette(input_city):
    session = HTMLSession()
    url = City_Grabber(input_city)
    r = session.get(url)
    html = r.html
    if r.status_code != 200:
        return "Some error occurred..."
    test_if_works = "#__next > div > div > div.ccl-d523c73794f30c03.ccl-917a4d5b8cd3a9e3.ccl-71fbf9dc5f85ebd4 > div > div.HomeLayout-b45e85df675abd0e > div > ul > li > span > div > div > h3"
    is_it_there = html.find(test_if_works)
    if is_it_there != []:
        return "Not available for this region. "
    path = '#__next > div > div > div.ccl-d523c73794f30c03.ccl-917a4d5b8cd3a9e3.ccl-71fbf9dc5f85ebd4 > div > div.HomeLayout-b45e85df675abd0e > div > ul > li > div > div > a'
    Restaurants = []
    Loop_over = r.html.find(path)
    for item in Loop_over:
        Restaurants.append(item.attrs["aria-label"])
    Restaurant_info = []
    for item in Restaurants:
        resto_name = re.split("(Bezorgt)",item)[0]
        Delivery_time = re.findall("Bezorgt[^B.]*",item)
        if Delivery_time == []:
            Delivery_time = ["Not given"]
        What = re.findall("Serveert.*",item)
        if What == []:
            What == ["Not Available"]
        Restaurant_info.append([resto_name,Delivery_time,What])
    return Restaurant_info

# %%
restaurant_roulette("Gent")
# Out:
# [['Restaurant De Kastart ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Pasta en Belgisch']],
#  ['Restaurant Hawaiian Poké Bowl - Kalandestraat ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Poke bowl, Hawaïaans, Gezond en Sushi']],
#  ["Restaurant McDonald's Korenmarkt ",
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Bakkerij Aernoudt - Gentbrugge ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Drankjes, Belegde broodjes, Salades en Ontbijt']],
#  ["Restaurant McDonald's Martelaarslaan ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Panos Veldstraat ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ['Restaurant Fitchen  ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Gezond, Belgisch, Wraps en Salades']],
#  ["Restaurant Paul's Boutique Station  ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Quick Giant Bar Gent ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Burgers, Belgisch en Amerikaans']],
#  ['Restaurant Au Pain Marie ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Belgisch, Salades en Belegde broodjes']],
#  ['Restaurant Oats Day Long ',
#   ['Bezorgt binnen 20 tot 30 minuten'],
#   ['Serveert Açai, Brunch, Gezond en Ontbijt']],
#  ['Restaurant CASPER Gent ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Amerikaans, Belgisch, Italiaans en Dessert']],
#  ['Restaurant Souplounge ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Salades en Gezond']],
#  ['Restaurant Panos Walpoort ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ['Restaurant Moochie ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert IJs, Dessert en Belgisch']],
#  ['Restaurant Pizza Factory  ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Italiaans, Pizza en Snacks']],
#  ['Restaurant Panos Lange Munt ',
#   ['Bezorgt binnen 20 tot 30 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ['Restaurant Panos Gent-Zuid ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ['Restaurant Beiruti ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Libanees']],
#  ['Restaurant Soepermarkt Gent ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Kip, Gezond en Soep']],
#  ['Restaurant Le Pain Quotidien ',
#   ['Bezorgt binnen 25 tot 45 minuten'],
#   ['Serveert Belgisch, Ontbijt en Gezond']],
#  ['Restaurant Crèmerie Marie ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Amerikaans, Belgisch, Dessert en Salades']],
#  ['Restaurant Belchicken Overpoortstraat ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Amerikaans, Burgers, Wraps en Salades']],
#  ['Restaurant Ikura Sushi ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Sushi, Japans en Aziatisch']],
#  ['Restaurant Pinocchio Gent ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Pizza']],
#  ['Restaurant Pasta La Vista ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans, Pasta en Gezond']],
#  ["Restaurant O'yo ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Salades, Ontbijt en Gezond']],
#  ['Restaurant Sobo ',
#   ['Bezorgt binnen 20 tot 30 minuten'],
#   ['Serveert Poke bowl en Salades']],
#  ["Restaurant Julie's House Shop ",
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Dessert, Belgisch, Ontbijt en Brunch']],
#  ['Restaurant Cappellini ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans en Pasta']],
#  ['Restaurant WASBAR Kalandestraat ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Burgers, Bagels, Salades en Ontbijt']],
#  ['Restaurant Gulzig ',
#   ['Bezorgt binnen 25 tot 45 minuten'],
#   ['Serveert Dessert, Kip, Spaans en BBQ']],
#  ["Restaurant Judy's Lobster Shack ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Vis, schelp- en schaaldieren, Snacks, Amerikaans en Belegde broodjes']],
#  ['Restaurant Mon Dada ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Italiaans, Pasta, Açai en Gezond']],
#  ['Restaurant Borsalino - San Marino ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans, Pizza en Pasta']],
#  ['Restaurant Donut Boutique ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Dessert en Donuts']],
#  ['Restaurant OGent ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Gezond, Salades, Burgers en Wraps']],
#  ['Restaurant The Noodles  ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Aziatisch en Noedels']],
#  ["Restaurant Chapo's Tex-Mexican Food ",
#   ['Bezorgt binnen 15 tot 15 minuten'],
#   ["Serveert Burrito's, Wraps en Mexicaans"]],
#  ['Restaurant Renaissance Ghent ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Belegde broodjes, Salades en Belgisch']],
#  ['Restaurant Knol & kool ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Gezond en Salades']],
#  ['Restaurant Les Tartes de Françoise ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Belgisch en Dessert']],
#  ['Restaurant Asian Corner ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Thais en Noedels']],
#  ['Restaurant Plus+ ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Salades en Gezond']],
#  ['Restaurant Basic Italian ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Italiaans, Belgisch, Pasta en Drankjes']],
#  ['Restaurant Tasty World Hoogpoort ',
#   ['Bezorgt binnen 25 tot 45 minuten'],
#   ['Serveert Burgers']],
#  ['Restaurant Himschoot  ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Brunch, Belgisch en Ontbijt']],
#  ['Restaurant Teskaffee ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Ontbijt, Brunch, Koffie en Thee']],
#  ['Restaurant Sandwichbar Mina ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Belegde broodjes en Boodschappen']],
#  ['Restaurant Foodmaker  ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Belegde broodjes, Salades, Gezond en Wraps']],
#  ['Restaurant Souperette ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Belgisch, Belegde broodjes en Salades']],
#  ['Restaurant The Sweet Lab. ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Dessert']],
#  ['Restaurant Traiteur Toulouse ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Dessert, Salades, Pasta en Gezond']],
#  ['Restaurant Planet Yoghurt - Planet Pasta ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Kip, Pasta, Italiaans en IJs']],
#  ['Restaurant Pure. by Pascale Naessens ',
#   ['Bezorgt binnen 30 tot 45 minuten'],
#   ['Serveert Gezond, Midden-Oosters en Salades']],
#  ['Restaurant Gloria ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Italiaans']],
#  ['Restaurant Pitza Service Gent ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Pizza en Italiaans']],
#  ['Restaurant Full Monty ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Italiaans en Amerikaans']],
#  ['Restaurant Hot Falafel ',
#   ['Bezorgt binnen 35 tot 55 minuten'],
#   ['Serveert Falafel en Libanees']],
#  ['Restaurant Neuhaus Gent ',
#   ['Bezorgt binnen 20 tot 30 minuten'],
#   ['Serveert Belgisch en Dessert']],
#  ['Restaurant Hacked ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Belgisch']],
#  ['Restaurant LiQ Gent ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Dessert, IJs, Belgisch en Amerikaans']],
#  ['Restaurant Deliveroo E-Gift Card Shop ',
#   ['Bezorgt binnen 10 tot 10 minuten'],
#   []],
#  ['Restaurant Bocca ', ['Bezorgt om 12:00 '], ['Serveert Italiaans en Pasta']],
#  ['Restaurant Bavet Muinkkaai ',
#   ['Bezorgt om 12:00 '],
#   ['Serveert Pasta, Belgisch en Italiaans']],
#  ['Restaurant Kapsalon Gent ',
#   ['Bezorgt om 16:45 '],
#   ['Serveert Mediterraans, Mexicaans, Kip en Curry']],
#  ['Restaurant Holy Guacamoly Zuid ',
#   ['Bezorgt om 12:00 '],
#   ["Serveert Burrito's, Mexicaans, Wraps en Gezond"]],
#  ['Restaurant Bavet Verloren Kost ',
#   ['Bezorgt om 12:00 '],
#   ['Serveert Pasta, Belgisch en Italiaans']],
#  ['Restaurant De Orchidee ',
#   ['Bezorgt om 12:00 '],
#   ['Serveert Thais en Noedels']],
#  ['Restaurant Twilight Sushi ',
#   ['Bezorgt om 12:45 '],
#   ['Serveert Sushi, Japans en Snacks']],
#  ['Restaurant Balls & Glory Ghent ',
#   ['Bezorgt om 12:00 '],
#   ['Serveert Kip, Belgisch en Salades']],
#  ['Restaurant De Appelier ', ['Bezorgt om 12:00 '], ['Serveert Belgisch']],
#  ['Restaurant Collina 2 go ',
#   ['Bezorgt om 12:00 '],
#   ['Serveert Italiaans en Pasta']],
#  ['Restaurant thaithanee ', ['Bezorgt om 12:00 '], ['Serveert Thais en Kip']],
#  ['Restaurant SUGO Pizza ',
#   ['Bezorgt om 12:15 '],
#   ['Serveert Pizza en Italiaans']],
#  ["Restaurant Seli's Noodlebar ",
#   ['Bezorgt om 12:15 '],
#   ['Serveert Noedels en Chinees']],
#  ['Restaurant Oh My Poké ',
#   ['Bezorgt om 12:15 '],
#   ['Serveert Hawaïaans, Poke bowl en Gezond']],
#  ['Restaurant Orientali Streetfood Bar ',
#   ['Bezorgt om 12:15 '],
#   ['Serveert Thais, Kip, Curry en Poke bowl']],
#  ["Restaurant Dunkin' Donuts ",
#   ['Bezorgt om 08:30 '],
#   ['Serveert Amerikaans, Donuts, IJs en Milkshakes']],
#  ["Restaurant Barney's Burger ", ['Bezorgt om 12:15 '], ['Serveert Burgers']],
#  ['Restaurant India Palace ',
#   ['Bezorgt om 12:15 '],
#   ['Serveert Nepalees en Indiaas']],
#  ['Restaurant Unique Asia Restaurant ',
#   ['Bezorgt om 12:15 '],
#   ['Serveert Aziatisch']],
#  ['Restaurant Komeet  ',
#   ['Bezorgt om 12:15 '],
#   ['Serveert Amerikaans, Dessert en Burgers']],
#  ['Restaurant Otomat  ',
#   ['Bezorgt om 12:30 '],
#   ['Serveert Italiaans, Pizza, Alcohol en Drankjes']],
#  ['Restaurant Ocean Sushi ',
#   ['Bezorgt om 12:30 '],
#   ['Serveert Sushi en Japans']],
#  ['Restaurant Poule & Poulette ',
#   ['Bezorgt om 12:30 '],
#   ['Serveert Kip, Burgers en Gefrituurde kip']],
#  ['Restaurant JACK Premium Burgers - Centrum ',
#   ['Bezorgt om 12:30 '],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Sushi Plaza ',
#   ['Bezorgt om 12:30 '],
#   ['Serveert Japans, Sushi, Soep en Salades']],
#  ['Restaurant Bavet Hooiaard ',
#   ['Bezorgt om 12:30 '],
#   ['Serveert Pasta, Belgisch en Italiaans']],
#  ['Restaurant Jilles Beer & Burgers
# <b>limit_output extension: Maximum message size of 10000 exceeded with 15751 characters</b>

# %%
def City_Grabber(input_city):
    session = HTMLSession()
    url = "https://google.be/search?q=deliveroo+" + input_city
    r = session.get(url)
    html = r.html
    for item in html.find("#search"):
        link = item.find(".g")[0]
        first_link = link.find("a")[0].attrs["href"]
    return first_link

# %%
def Random_restaurant(input_city, is_open = False):
    if is_open:
        result = Check_if_open(input_city)
    else:
        result = restaurant_roulette(input_city)
    randint = random.randint(0,len(result))
    return result[randint]
print(Random_restaurant("Leuven",True))
# Out:
# ['Restaurant Banh-Mi Express ', ['Bezorgt binnen 15 tot 25 minuten'], ['Serveert Vietnamees, Ramen, Noedels en Belegde broodjes']]

# %%
def Check_if_open(input_city):
    open_restaurants = []
    results = restaurant_roulette(input_city)
    for item in results:
        if re.findall("minuten",item[1][0]) == []:
            continue
        else:
            open_restaurants.append(item)
    return open_restaurants

# %%
# Out:
# [['Restaurant De Kastart ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Pasta en Belgisch']],
#  ['Restaurant Hawaiian Poké Bowl - Kalandestraat ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Poke bowl, Hawaïaans, Gezond en Sushi']],
#  ["Restaurant McDonald's Korenmarkt ",
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Panos Lange Munt ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ["Restaurant McDonald's Martelaarslaan ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Fitchen  ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Gezond, Belgisch, Wraps en Salades']],
#  ['Restaurant Panos Veldstraat ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ["Restaurant Paul's Boutique Station  ",
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Amerikaans en Burgers']],
#  ['Restaurant Bakkerij Aernoudt - Gentbrugge ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Drankjes, Belegde broodjes, Salades en Ontbijt']],
#  ['Restaurant Quick Giant Bar Gent ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Burgers, Belgisch en Amerikaans']],
#  ['Restaurant Au Pain Marie ',
#   ['Bezorgt binnen 20 tot 30 minuten'],
#   ['Serveert Belgisch, Salades en Belegde broodjes']],
#  ['Restaurant Oats Day Long ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Açai, Brunch, Gezond en Ontbijt']],
#  ['Restaurant Souplounge ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Salades en Gezond']],
#  ['Restaurant Panos Gent-Zuid ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ['Restaurant Panos Walpoort ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Belegde broodjes, Belgisch, Ontbijt en Salades']],
#  ['Restaurant Pizza Factory  ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans, Pizza en Snacks']],
#  ['Restaurant Moochie ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert IJs, Dessert en Belgisch']],
#  ['Restaurant Beiruti ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Libanees']],
#  ['Restaurant Le Pain Quotidien ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Belgisch, Ontbijt en Gezond']],
#  ['Restaurant Ikura Sushi ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Sushi, Japans en Aziatisch']],
#  ['Restaurant Soepermarkt Gent ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Kip, Gezond en Soep']],
#  ['Restaurant Crèmerie Marie ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Amerikaans, Belgisch, Dessert en Salades']],
#  ['Restaurant Belchicken Overpoortstraat ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Amerikaans, Burgers, Wraps en Salades']],
#  ['Restaurant Pinocchio Gent ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Pizza']],
#  ["Restaurant O'yo ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Salades, Ontbijt en Gezond']],
#  ['Restaurant Pasta La Vista ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans, Pasta en Gezond']],
#  ["Restaurant Julie's House Shop ",
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Dessert, Belgisch, Ontbijt en Brunch']],
#  ['Restaurant Sobo ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Poke bowl en Salades']],
#  ['Restaurant WASBAR Kalandestraat ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Burgers, Bagels, Salades en Ontbijt']],
#  ['Restaurant Gulzig ',
#   ['Bezorgt binnen 25 tot 45 minuten'],
#   ['Serveert Dessert, Kip, Spaans en BBQ']],
#  ['Restaurant Cappellini ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans en Pasta']],
#  ["Restaurant Judy's Lobster Shack ",
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Vis, schelp- en schaaldieren, Snacks, Amerikaans en Belegde broodjes']],
#  ['Restaurant Les Tartes de Françoise ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Belgisch en Dessert']],
#  ['Restaurant Mon Dada ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans, Pasta, Açai en Gezond']],
#  ['Restaurant Borsalino - San Marino ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Italiaans, Pizza en Pasta']],
#  ['Restaurant OGent ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Gezond, Salades, Burgers en Wraps']],
#  ['Restaurant Donut Boutique ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Dessert en Donuts']],
#  ["Restaurant Chapo's Tex-Mexican Food ",
#   ['Bezorgt binnen 15 tot 15 minuten'],
#   ["Serveert Burrito's, Wraps en Mexicaans"]],
#  ['Restaurant The Noodles  ',
#   ['Bezorgt binnen 15 tot 25 minuten'],
#   ['Serveert Aziatisch en Noedels']],
#  ['Restaurant Renaissance Ghent ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Belegde broodjes, Salades en Belgisch']],
#  ['Restaurant Knol & kool ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Gezond en Salades']],
#  ['Restaurant Asian Corner ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Thais en Noedels']],
#  ['Restaurant Foodmaker  ',
#   ['Bezorgt binnen 10 tot 20 minuten'],
#   ['Serveert Belegde broodjes, Salades, Gezond en Wraps']],
#  ['Restaurant Basic Italian ',
#   ['Bezorgt binnen 25 tot 40 minuten'],
#   ['Serveert Italiaans, Belgisch, Pasta en Drankjes']],
#  ['Restaurant Himschoot  ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Brunch, Belgisch en Ontbijt']],
#  ['Restaurant Teskaffee ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Ontbijt, Brunch, Koffie en Thee']],
#  ['Restaurant Sandwichbar Mina ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Belegde broodjes en Boodschappen']],
#  ['Restaurant Souperette ',
#   ['Bezorgt binnen 20 tot 30 minuten'],
#   ['Serveert Belgisch, Belegde broodjes en Salades']],
#  ['Restaurant Traiteur Toulouse ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Dessert, Salades, Pasta en Gezond']],
#  ['Restaurant Planet Yoghurt - Planet Pasta ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Kip, Pasta, Italiaans en IJs']],
#  ['Restaurant Pitza Service Gent ',
#   ['Bezorgt binnen 20 tot 35 minuten'],
#   ['Serveert Pizza en Italiaans']],
#  ['Restaurant Hot Falafel ',
#   ['Bezorgt binnen 30 tot 50 minuten'],
#   ['Serveert Falafel en Libanees']],
#  ['Restaurant Neuhaus Gent ',
#   ['Bezorgt binnen 15 tot 30 minuten'],
#   ['Serveert Belgisch en Dessert']],
#  ['Restaurant Deliveroo E-Gift Card Shop ',
#   ['Bezorgt binnen 10 tot 10 minuten'],
#   []]]
